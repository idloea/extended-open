# %% [markdown]
# # Analysis for 20220518-102651.xlsx

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
from ast import literal_eval
from typing import List, Union
from matplotlib.backends.backend_pdf import PdfPages
from datetime import datetime
from scipy import interpolate
pd.set_option('display.max_columns', None)

# %%
excel_sheet_path = r'C:\python\personal\my-open\notebooks\20230518-102651\data\20230518-102651.xlsx'
data = pd.read_excel(excel_sheet_path, engine='openpyxl')

# %%
data.head()
# Out:
#                                       FolderName  \
# 0  20230518-102738_1_Commercial-275-bed Hospital
# 1  20230518-102808_2_Commercial-275-bed Hospital
# 2  20230518-102838_3_Commercial-275-bed Hospital
# 3  20230518-102909_4_Commercial-275-bed Hospital
# 4  20230518-102940_5_Commercial-275-bed Hospital
#
#    rated_photovoltaic_kilowatts  simulation_time_series_resolution_in_minutes  \
# 0                           400                                             1
# 1                           400                                             1
# 2                           400                                             1
# 3                           400                                             1
# 4                           400                                             1
#
#    energy_management_system_time_series_resolution_in_minutes  \
# 0                                                 15
# 1                                                 15
# 2                                                 15
# 3                                                 15
# 4                                                 15
#
#    max_storage_asset_energy_in_kilowatt_hour  \
# 0                                        500
# 1                                        500
# 2                                        500
# 3                                        500
# 4                                        500
#
#    min_storage_asset_energy_in_kilowatt_hour  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    max_storage_asset_active_power_in_kilowatts  \
# 0                                          500
# 1                                          500
# 2                                          500
# 3                                          500
# 4                                          500
#
#    min_storage_asset_active_power_in_kilowatts  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    initial_storage_asset_energy_level_percentage  \
# 0                                              4
# 1                                              4
# 2                                              4
# 3                                              4
# 4                                              4
#
#    required_storage_asset_terminal_energy_level_percentage  \
# 0                                                 50
# 1                                                 50
# 2                                                 50
# 3                                                 50
# 4                                                 50
#
#    storage_asset_absolute_active_power_in_kilowatts  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    storage_asset_degradation_ratio_in_euros_per_kilowatt_hour  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    storage_asset_charging_efficiency_percentage  \
# 0                                           100
# 1                                           100
# 2                                           100
# 3                                           100
# 4                                           100
#
#    storage_asset_charging_efficiency_for_the_optimizer_percentage  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#    max_inside_degree_celsius  min_inside_degree_celsius  \
# 0                         25                         21
# 1                         25                         21
# 2                         25                         21
# 3                         25                         21
# 4                         25                         21
#
#    initial_inside_degree_celsius  max_consumed_electric_heating_kilowatts  \
# 0                             21                                      400
# 1                             21                                      400
# 2                             21                                      400
# 3                             21                                      400
# 4                             21                                      400
#
#    max_consumed_electric_cooling_kilowatts  \
# 0                                      400
# 1                                      400
# 2                                      400
# 3                                      400
# 4                                      400
#
#    heat_pump_coefficient_of_performance  chiller_coefficient_of_performance  \
# 0                                     3                                   1
# 1                                     3                                   1
# 2                                     3                                   1
# 3                                     3                                   1
# 4                                     3                                   1
#
#    building_thermal_capacitance_in_kilowatts_hour_per_degree_celsius  \
# 0                                                500
# 1                                                500
# 2                                                500
# 3                                                500
# 4                                                500
#
#    building_thermal_resistance_in_degree_celsius_per_kilowatts  \
# 0                                             0.0337
# 1                                             0.0337
# 2                                             0.0337
# 3                                             0.0337
# 4                                             0.0337
#
#    export_prices_in_euros_per_kilowatt_hour  \
# 0                                     0.189
# 1                                     0.189
# 2                                     0.189
# 3                                     0.189
# 4                                     0.189
#
#    demand_charge_in_euros_per_kilowatt  max_import_kilowatts  \
# 0                                    0                   500
# 1                                    0                   500
# 2                                    0                   500
# 3                                    0                   500
# 4                                    0                   500
#
#    max_export_kilowatts  offered_kilowatts_in_frequency_response  \
# 0                  -500                                        0
# 1                  -500                                        0
# 2                  -500                                        0
# 3                  -500                                        0
# 4                  -500                                        0
#
#    max_frequency_response_state_of_charge  \
# 0                                     0.6
# 1                                     0.6
# 2                                     0.6
# 3                                     0.6
# 4                                     0.6
#
#    min_frequency_response_state_of_charge  \
# 0                                     0.4
# 1                                     0.4
# 2                                     0.4
# 3                                     0.4
# 4                                     0.4
#
#    frequency_response_price_in_euros_per_kilowatt_hour  \
# 0                                             0.0059
# 1                                             0.0059
# 2                                             0.0059
# 3                                             0.0059
# 4                                             0.0059
#
#    grid_1_voltage_level_in_kilo_volts  grid_2_voltage_level_in_kilo_volts  \
# 0                                  20                                 0.4
# 1                                  20                                 0.4
# 2                                  20                                 0.4
# 3                                  20                                 0.4
# 4                                  20                                 0.4
#
#    grid_3_voltage_level_in_kilo_volts  \
# 0                                 0.4
# 1                                 0.4
# 2                                 0.4
# 3                                 0.4
# 4                                 0.4
#
#    transformer_apparent_power_in_mega_volt_ampere  \
# 0                                             0.4
# 1                                             0.4
# 2                                             0.4
# 3                                             0.4
# 4                                             0.4
#
#    length_from_bus_2_to_bus_3_in_km  blackout_start_time_in_hours  \
# 0                               0.1                            11
# 1                               0.1                            11
# 2                               0.1                            11
# 3                               0.1                            11
# 4                               0.1                            11
#
#    blackout_stop_time_in_hours  save_plots  \
# 0                         12.5       False
# 1                         12.5       False
# 2                         12.5       False
# 3                         12.5       False
# 4                         12.5       False
#
#               photovoltaic_generation_data_file_path  \
# 0  data/solar_radiation/pamplona/1_min/2022-01-01...
# 1  data/solar_radiation/pamplona/1_min/2022-01-02...
# 2  data/solar_radiation/pamplona/1_min/2022-01-03...
# 3  data/solar_radiation/pamplona/1_min/2022-01-04...
# 4  data/solar_radiation/pamplona/1_min/2022-01-05...
#
#                     electric_load_data_file_path data_strategy  \
# 0  data/electric_loads/considered_building_types  MeteoNavarra
# 1  data/electric_loads/considered_building_types  MeteoNavarra
# 2  data/electric_loads/considered_building_types  MeteoNavarra
# 3  data/electric_loads/considered_building_types  MeteoNavarra
# 4  data/electric_loads/considered_building_types  MeteoNavarra
#
#                        ambient_temperature_file_path   market  \
# 0  data/ambient_temperature/pamplona/20220115_amb...  Spanish
# 1  data/ambient_temperature/pamplona/20220215_amb...  Spanish
# 2  data/ambient_temperature/pamplona/20220315_amb...  Spanish
# 3  data/ambient_temperature/pamplona/20220415_amb...  Spanish
# 4  data/ambient_temperature/pamplona/20220515_amb...  Spanish
#
#    import_period_prices.P1  import_period_prices.P2  import_period_prices.P3  \
# 0                   0.1395                   0.1278                    0.111
# 1                   0.1395                   0.1278                    0.111
# 2                   0.1395                   0.1278                    0.111
# 3                   0.1395                   0.1278                    0.111
# 4                   0.1395                   0.1278                    0.111
#
#    import_period_prices.P4  import_period_prices.P5  import_period_prices.P6  \
# 0                   0.1014                   0.0927                   0.0871
# 1                   0.1014                   0.0927                   0.0871
# 2                   0.1014                   0.0927                   0.0871
# 3                   0.1014                   0.0927                   0.0871
# 4                   0.1014                   0.0927                   0.0871
#
#                       buses_voltage_angle_in_degrees  \
# 0  [[0.0, -2.3951697643387164, -3.259090153682367...
# 1  [[0.0, -1.5797317440054035, -2.145666664095071...
# 2  [[0.0, -0.8147567975550066, -1.104240168130317...
# 3  [[0.0, -1.0248455780610335, -1.389971268381915...
# 4  [[0.0, -0.7142447014344591, -0.967611137719895...
#
#                      buses_active_power_in_kilowatts  \
# 0  [[-288.1100621061704, 0.0, 250.71931560876405]...
# 1  [[-190.20332931710308, 0.0, 173.2503747170207]...
# 2  [[-98.3657717213743, 0.0, 92.9024722460945], [...
# 3  [[-123.58075645120803, 0.0, 115.7000132121146]...
# 4  [[-86.30505265465385, 0.0, 81.80117101603292],...
#
#     buses_reactive_power_in_kilovolt_ampere_reactive  \
# 0  [[-16.35650436202681, 0.0, 0.0], [-16.35650436...
# 1  [[-7.093392131914574, 0.0, 0.0], [-7.093392131...
# 2  [[-1.878627503088791, 0.0, 0.0], [-1.878627503...
# 3  [[-2.976985199600601, 0.0, 0.0], [-2.976985199...
# 4  [[-1.4423141520670528, 0.0, 0.0], [-1.44231415...
#
#                     market_active_power_in_kilowatts  \
# 0  [288.1100621061704, 288.1100621061704, 288.110...
# 1  [190.20332931710308, 190.20332931710308, 190.2...
# 2  [98.3657717213743, 98.3657717213743, 98.365771...
# 3  [123.58075645120803, 123.58075645120803, 123.5...
# 4  [86.30505265465385, 86.30505265465385, 86.3050...
#
#    market_reactive_power_in_kilovolt_ampere_reactive  \
# 0  [16.35650436202681, 16.35650436202681, 16.3565...
# 1  [7.093392131914574, 7.093392131914574, 7.09339...
# 2  [1.878627503088791, 1.878627503088791, 1.87862...
# 3  [2.976985199600601, 2.976985199600601, 2.97698...
# 4  [1.4423141520670528, 1.4423141520670528, 1.442...
#
#                            buses_voltage_in_per_unit  \
# 0  [[1.0, 0.9882421049296655, 0.8728775078644493]...
# 1  [[1.0, 0.9925930000278556, 0.9167119360105046]...
# 2  [[1.0, 0.9963474269620033, 0.9573989107030836]...
# 3  [[1.0, 0.995347756299463, 0.9462667431553236],...
# 4  [[1.0, 0.9968173001728816, 0.9627136200569099]...
#
#                     active_power_demand_in_kilowatts  revenue  \
# 0  [6.553399999999999, 6.553399999999999, 6.55339...   837.49
# 1  [6.8292, 6.8292, 6.8292, 6.8292, 6.91179999999...   583.82
# 2  [5.9486, 5.9486, 5.9486, 5.9486, 5.98640000000...    86.16
# 3  [5.483800000000001, 5.483800000000001, 5.48380...   254.95
# 4  [5.758200000000001, 5.758200000000001, 5.75820...   -41.03
#
#                active_power_demand_base_in_kilowatts  \
# 0  [6.553400000000001, 6.553400000000001, 6.55340...
# 1  [6.8292, 6.8292, 6.8292, 6.8292, 6.8292, 6.829...
# 2  [5.9486, 5.9486, 5.9486, 5.9486, 5.9486, 5.948...
# 3  [5.4838000000000005, 5.4838000000000005, 5.483...
# 4  [5.7582, 5.7582, 5.7582, 5.7582, 5.7582, 5.758...
#
#                   imported_active_power_in_kilowatts  \
# 0  [[499.9999999981634], [499.9999999981608], [49...
# 1  [[499.9999999605623], [499.99999996051207], [4...
# 2  [[499.99999991232636], [499.99999991267646], [...
# 3  [[499.9999999905912], [499.9999999906174], [49...
# 4  [[499.9999999662609], [499.9999999662787], [49...
#
#                   exported_active_power_in_kilowatts  \
# 0  [[249.28068438939937], [246.71989086095172], [...
# 1  [[326.74962524354174], [327.44164314720524], [...
# 2  [[407.0975276662319], [410.03110381635304], [4...
# 3  [[384.29998677847664], [373.6164212920582], [3...
# 4  [[418.19882895022755], [404.19706222472087], [...
#
#              building_power_consumption_in_kilowatts  \
# 0  [[244.16591560715298], [246.72670913556766], [...
# 1  [[166.42117467358946], [165.72915676985767], [...
# 2  [[86.9538721655212], [84.02029601456186], [84....
# 3  [[110.21621320192189], [120.89977868838022], [...
# 4  [[76.04297097945201], [90.04473770500485], [91...
#
#                ambient_temperature_in_degree_celsius  \
# 0  [-3.6851740626763085, -3.9440702927850753, -4....
# 1  [4.174819364103925, 4.244782243962801, 4.10928...
# 2  [12.208963769453646, 12.505548100028602, 12.42...
# 3  [9.857140880334313, 8.777032376115372, 8.98475...
# 4  [13.312055782015861, 11.896477041113585, 11.74...
#
#     building_internal_temperature_in_celsius_degrees  \
# 0  [20.999999999999655, 21.000000000075094, 21.00...
# 1  [20.99999999999969, 21.000000001803855, 21.000...
# 2  [20.99999999999927, 21.000000003572673, 21.000...
# 3  [20.999999999999446, 21.000000000511797, 21.00...
# 4  [20.99999999976173, 21.00000000168883, 21.0000...
#
#                       hvac_active_power_in_kilowatts  \
# 0  [244.16591560715298, 244.16591560715298, 244.1...
# 1  [166.42117467358946, 166.42117467358946, 166.4...
# 2  [86.9538721655212, 86.9538721655212, 86.953872...
# 3  [110.21621320192189, 110.21621320192189, 110.2...
# 4  [76.04297097945201, 76.04297097945201, 76.0429...
#
#         storage_asset_accumulated_power_in_kilowatts
# 0  [244.16591560715298, 246.72670913556766, 252.0...
# 1  [166.42117467358946, 165.72915676985767, 167.0...
# 2  [86.9538721655212, 84.02029601456186, 84.77945...
# 3  [110.21621320192189, 120.89977868838022, 118.8...
# 4  [76.04297097945201, 90.04473770500485, 91.5328...

# %%
data.shape
# Out:
# (72, 66)

# %%
data.columns
# Out:
# Index(['FolderName', 'rated_photovoltaic_kilowatts',
#        'simulation_time_series_resolution_in_minutes',
#        'energy_management_system_time_series_resolution_in_minutes',
#        'max_storage_asset_energy_in_kilowatt_hour',
#        'min_storage_asset_energy_in_kilowatt_hour',
#        'max_storage_asset_active_power_in_kilowatts',
#        'min_storage_asset_active_power_in_kilowatts',
#        'initial_storage_asset_energy_level_percentage',
#        'required_storage_asset_terminal_energy_level_percentage',
#        'storage_asset_absolute_active_power_in_kilowatts',
#        'storage_asset_degradation_ratio_in_euros_per_kilowatt_hour',
#        'storage_asset_charging_efficiency_percentage',
#        'storage_asset_charging_efficiency_for_the_optimizer_percentage',
#        'max_inside_degree_celsius', 'min_inside_degree_celsius',
#        'initial_inside_degree_celsius',
#        'max_consumed_electric_heating_kilowatts',
#        'max_consumed_electric_cooling_kilowatts',
#        'heat_pump_coefficient_of_performance',
#        'chiller_coefficient_of_performance',
#        'building_thermal_capacitance_in_kilowatts_hour_per_degree_celsius',
#        'building_thermal_resistance_in_degree_celsius_per_kilowatts',
#        'export_prices_in_euros_per_kilowatt_hour',
#        'demand_charge_in_euros_per_kilowatt', 'max_import_kilowatts',
#        'max_export_kilowatts', 'offered_kilowatts_in_frequency_response',
#        'max_frequency_response_state_of_charge',
#        'min_frequency_response_state_of_charge',
#        'frequency_response_price_in_euros_per_kilowatt_hour',
#        'grid_1_voltage_level_in_kilo_volts',
#        'grid_2_voltage_level_in_kilo_volts',
#        'grid_3_voltage_level_in_kilo_volts',
#        'transformer_apparent_power_in_mega_volt_ampere',
#        'length_from_bus_2_to_bus_3_in_km', 'blackout_start_time_in_hours',
#        'blackout_stop_time_in_hours', 'save_plots',
#        'photovoltaic_generation_data_file_path',
#        'electric_load_data_file_path', 'data_strategy',
#        'ambient_temperature_file_path', 'market', 'import_period_prices.P1',
#        'import_period_prices.P2', 'import_period_prices.P3',
#        'import_period_prices.P4', 'import_period_prices.P5',
#        'import_period_prices.P6', 'buses_voltage_angle_in_degrees',
#        'buses_active_power_in_kilowatts',
#        'buses_reactive_power_in_kilovolt_ampere_reactive',
#        'market_active_power_in_kilowatts',
#        'market_reactive_power_in_kilovolt_ampere_reactive',
#        'buses_voltage_in_per_unit', 'active_power_demand_in_kilowatts',
#        'revenue', 'active_power_demand_base_in_kilowatts',
#        'imported_active_power_in_kilowatts',
#        'exported_active_power_in_kilowatts',
#        'building_power_consumption_in_kilowatts',
#        'ambient_temperature_in_degree_celsius',
#        'building_internal_temperature_in_celsius_degrees',
#        'hvac_active_power_in_kilowatts',
#        'storage_asset_accumulated_power_in_kilowatts'],
#       dtype='object')

# %% [markdown]
# # Reformat list columns
#
# The list or array columns are string, let's modify them:

# %%
for column in data.columns:
    try:
        data[column] = data[column].map(literal_eval)
    except:
        print(f'{column} column not possible to transform')
# Out:
# FolderName column not possible to transform
# rated_photovoltaic_kilowatts column not possible to transform
# simulation_time_series_resolution_in_minutes column not possible to transform
# energy_management_system_time_series_resolution_in_minutes column not possible to transform
# max_storage_asset_energy_in_kilowatt_hour column not possible to transform
# min_storage_asset_energy_in_kilowatt_hour column not possible to transform
# max_storage_asset_active_power_in_kilowatts column not possible to transform
# min_storage_asset_active_power_in_kilowatts column not possible to transform
# initial_storage_asset_energy_level_percentage column not possible to transform
# required_storage_asset_terminal_energy_level_percentage column not possible to transform
# storage_asset_absolute_active_power_in_kilowatts column not possible to transform
# storage_asset_degradation_ratio_in_euros_per_kilowatt_hour column not possible to transform
# storage_asset_charging_efficiency_percentage column not possible to transform
# storage_asset_charging_efficiency_for_the_optimizer_percentage column not possible to transform
# max_inside_degree_celsius column not possible to transform
# min_inside_degree_celsius column not possible to transform
# initial_inside_degree_celsius column not possible to transform
# max_consumed_electric_heating_kilowatts column not possible to transform
# max_consumed_electric_cooling_kilowatts column not possible to transform
# heat_pump_coefficient_of_performance column not possible to transform
# chiller_coefficient_of_performance column not possible to transform
# building_thermal_capacitance_in_kilowatts_hour_per_degree_celsius column not possible to transform
# building_thermal_resistance_in_degree_celsius_per_kilowatts column not possible to transform
# export_prices_in_euros_per_kilowatt_hour column not possible to transform
# demand_charge_in_euros_per_kilowatt column not possible to transform
# max_import_kilowatts column not possible to transform
# max_export_kilowatts column not possible to transform
# offered_kilowatts_in_frequency_response column not possible to transform
# max_frequency_response_state_of_charge column not possible to transform
# min_frequency_response_state_of_charge column not possible to transform
# frequency_response_price_in_euros_per_kilowatt_hour column not possible to transform
# grid_1_voltage_level_in_kilo_volts column not possible to transform
# grid_2_voltage_level_in_kilo_volts column not possible to transform
# grid_3_voltage_level_in_kilo_volts column not possible to transform
# transformer_apparent_power_in_mega_volt_ampere column not possible to transform
# length_from_bus_2_to_bus_3_in_km column not possible to transform
# blackout_start_time_in_hours column not possible to transform
# blackout_stop_time_in_hours column not possible to transform
# save_plots column not possible to transform
# photovoltaic_generation_data_file_path column not possible to transform
# electric_load_data_file_path column not possible to transform
# data_strategy column not possible to transform
# ambient_temperature_file_path column not possible to transform
# market column not possible to transform
# import_period_prices.P1 column not possible to transform
# import_period_prices.P2 column not possible to transform
# import_period_prices.P3 column not possible to transform
# import_period_prices.P4 column not possible to transform
# import_period_prices.P5 column not possible to transform
# import_period_prices.P6 column not possible to transform
# buses_voltage_angle_in_degrees column not possible to transform
# buses_active_power_in_kilowatts column not possible to transform
# buses_reactive_power_in_kilovolt_ampere_reactive column not possible to transform
# buses_voltage_in_per_unit column not possible to transform
# revenue column not possible to transform

# %% [markdown]
# # Plots

# %%
for column in data.columns:
    first_row_data = data[column].iloc[0]
    print(f'{column} - Type: {type(first_row_data)}')
    print(first_row_data)
# Out:
# FolderName - Type: <class 'str'>
# 20230518-102738_1_Commercial-275-bed Hospital
# rated_photovoltaic_kilowatts - Type: <class 'numpy.int64'>
# 400
# simulation_time_series_resolution_in_minutes - Type: <class 'numpy.int64'>
# 1
# energy_management_system_time_series_resolution_in_minutes - Type: <class 'numpy.int64'>
# 15
# max_storage_asset_energy_in_kilowatt_hour - Type: <class 'numpy.int64'>
# 500
# min_storage_asset_energy_in_kilowatt_hour - Type: <class 'numpy.int64'>
# 0
# max_storage_asset_active_power_in_kilowatts - Type: <class 'numpy.int64'>
# 500
# min_storage_asset_active_power_in_kilowatts - Type: <class 'numpy.int64'>
# 0
# initial_storage_asset_energy_level_percentage - Type: <class 'numpy.int64'>
# 4
# required_storage_asset_terminal_energy_level_percentage - Type: <class 'numpy.int64'>
# 50
# storage_asset_absolute_active_power_in_kilowatts - Type: <class 'numpy.float64'>
# nan
# storage_asset_degradation_ratio_in_euros_per_kilowatt_hour - Type: <class 'numpy.float64'>
# nan
# storage_asset_charging_efficiency_percentage - Type: <class 'numpy.int64'>
# 100
# storage_asset_charging_efficiency_for_the_optimizer_percentage - Type: <class 'numpy.int64'>
# 100
# max_inside_degree_celsius - Type: <class 'numpy.int64'>
# 25
# min_inside_degree_celsius - Type: <class 'numpy.int64'>
# 21
# initial_inside_degree_celsius - Type: <class 'numpy.int64'>
# 21
# max_consumed_electric_heating_kilowatts - Type: <class 'numpy.int64'>
# 400
# max_consumed_electric_cooling_kilowatts - Type: <class 'numpy.int64'>
# 400
# heat_pump_coefficient_of_performance - Type: <class 'numpy.int64'>
# 3
# chiller_coefficient_of_performance - Type: <class 'numpy.int64'>
# 1
# building_thermal_capacitance_in_kilowatts_hour_per_degree_celsius - Type: <class 'numpy.int64'>
# 500
# building_thermal_resistance_in_degree_celsius_per_kilowatts - Type: <class 'numpy.float64'>
# 0.0337
# export_prices_in_euros_per_kilowatt_hour - Type: <class 'numpy.float64'>
# 0.189
# demand_charge_in_euros_per_kilowatt - Type: <class 'numpy.int64'>
# 0
# max_import_kilowatts - Type: <class 'numpy.int64'>
# 500
# max_export_kilowatts - Type: <class 'numpy.int64'>
# -500
# offered_kilowatts_in_frequency_response - Type: <class 'numpy.int64'>
# 0
# max_frequency_response_state_of_charge - Type: <class 'numpy.float64'>
# 0.6
# min_frequency_response_state_of_charge - Type: <class 'numpy.float64'>
# 0.4
# frequency_response_price_in_euros_per_kilowatt_hour - Type: <class 'numpy.float64'>
# 0.0059
# grid_1_voltage_level_in_kilo_volts - Type: <class 'numpy.int64'>
# 20
# grid_2_voltage_level_in_kilo_volts - Type: <class 'numpy.float64'>
# 0.4
# grid_3_voltage_level_in_kilo_volts - Type: <class 'numpy.float64'>
# 0.4
# transformer_apparent_power_in_mega_volt_ampere - Type: <class 'numpy.float64'>
# 0.4
# length_from_bus_2_to_bus_3_in_km - Type: <class 'numpy.float64'>
# 0.1
# blackout_start_time_in_hours - Type: <class 'numpy.int64'>
# 11
# blackout_stop_time_in_hours - Type: <class 'numpy.float64'>
# 12.5
# save_plots - Type: <class 'numpy.bool_'>
# False
# photovoltaic_generation_data_file_path - Type: <class 'str'>
# data/solar_radiation/pamplona/1_min/2022-01-01_pamplona.csv
# electric_load_data_file_path - Type: <class 'str'>
# data/electric_loads/considered_building_types
# data_strategy - Type: <class 'str'>
# MeteoNavarra
# ambient_temperature_file_path - Type: <class 'str'>
# data/ambient_temperature/pamplona/20220115_ambient_temperature_upna.csv
# market - Type: <class 'str'>
# Spanish
# import_period_prices.P1 - Type: <class 'numpy.float64'>
# 0.1395
# import_period_prices.P2 - Type: <class 'numpy.float64'>
# 0.1278
326.2921169375113, 343.6996041605828, 386.8031758668321, 360.9209913625194, 273.231696121524, 263.61176913104765, 216.78620188591705, 194.9982124803753, 232.06657611998563, 96.81498353736667, 226.02549101704432, 168.0196217178345, 107.90655508149614, 44.174538763290556, 2.2403933891640616e-08, 2.5770824435092214e-08, 3.029369431624371e-08, 3.733497152601265e-08, 4.968456177856646e-08, 3.349632701832897e-08, 67.26176570039456, 188.909220340545, 203.28549526491273, 206.6524086335673, 215.72801269645097, 215.4092663674751, 218.78232733318399, 223.86870882962126, 223.79022433635282, 222.56473061239296, 224.0424427504655, 224.10235643123966, 228.33974327139094, 231.0726134899799, 235.61365356084775, 238.792386323145, 235.18877026815835, 234.13839431880587, 240.5792169769899, 243.05636141642094, 244.20991936728998, 243.76662313841175, 249.2780136087536, 3.1184169120514594e-09]

# %%
simulation_time_series_resolution_in_hours = data.simulation_time_series_resolution_in_minutes[0] / 60
hours_per_day = 24
number_of_time_intervals_per_day = int(hours_per_day / simulation_time_series_resolution_in_hours)

# %%
hours = simulation_time_series_resolution_in_hours * np.arange(number_of_time_intervals_per_day)
max_time = max(hours)
figure = plt.figure(num=None, figsize=(11, 4), dpi=80, facecolor='w', edgecolor='k')
plt.plot(hours, data.active_power_demand_base_in_kilowatts[0], '--', label='Demand')
plt.plot(hours, data.market_active_power_in_kilowatts[0], label='Imports')
plt.suptitle('Base Demand vs Imports from the Network')
subtitle = 'Case: ' + str(data.FolderName[0]) + ' - ' + 'Revenue[€]: ' + str(data.revenue[0])
plt.title(subtitle)
plt.ylabel('Power [kW]')
plt.xlabel('Time [h]')
plt.xlim(0, max_time)
plt.xticks(np.arange(0, max_time, step=1))
plt.legend()
plt.grid(True, alpha=0.5)
plt.tight_layout()

# %%
data.dtypes.unique()
# Out:
# array([dtype('O'), dtype('int64'), dtype('float64'), dtype('bool')],
#       dtype=object)

# %%
list_columns = []
for column in data.columns:
    print(column)
    print(type(column))
    if isinstance(data[column][0], list):
        list_columns.append(column)
# Out:
# FolderName
# <class 'str'>
# rated_photovoltaic_kilowatts
# <class 'str'>
# simulation_time_series_resolution_in_minutes
# <class 'str'>
# energy_management_system_time_series_resolution_in_minutes
# <class 'str'>
# max_storage_asset_energy_in_kilowatt_hour
# <class 'str'>
# min_storage_asset_energy_in_kilowatt_hour
# <class 'str'>
# max_storage_asset_active_power_in_kilowatts
# <class 'str'>
# min_storage_asset_active_power_in_kilowatts
# <class 'str'>
# initial_storage_asset_energy_level_percentage
# <class 'str'>
# required_storage_asset_terminal_energy_level_percentage
# <class 'str'>
# storage_asset_absolute_active_power_in_kilowatts
# <class 'str'>
# storage_asset_degradation_ratio_in_euros_per_kilowatt_hour
# <class 'str'>
# storage_asset_charging_efficiency_percentage
# <class 'str'>
# storage_asset_charging_efficiency_for_the_optimizer_percentage
# <class 'str'>
# max_inside_degree_celsius
# <class 'str'>
# min_inside_degree_celsius
# <class 'str'>
# initial_inside_degree_celsius
# <class 'str'>
# max_consumed_electric_heating_kilowatts
# <class 'str'>
# max_consumed_electric_cooling_kilowatts
# <class 'str'>
# heat_pump_coefficient_of_performance
# <class 'str'>
# chiller_coefficient_of_performance
# <class 'str'>
# building_thermal_capacitance_in_kilowatts_hour_per_degree_celsius
# <class 'str'>
# building_thermal_resistance_in_degree_celsius_per_kilowatts
# <class 'str'>
# export_prices_in_euros_per_kilowatt_hour
# <class 'str'>
# demand_charge_in_euros_per_kilowatt
# <class 'str'>
# max_import_kilowatts
# <class 'str'>
# max_export_kilowatts
# <class 'str'>
# offered_kilowatts_in_frequency_response
# <class 'str'>
# max_frequency_response_state_of_charge
# <class 'str'>
# min_frequency_response_state_of_charge
# <class 'str'>
# frequency_response_price_in_euros_per_kilowatt_hour
# <class 'str'>
# grid_1_voltage_level_in_kilo_volts
# <class 'str'>
# grid_2_voltage_level_in_kilo_volts
# <class 'str'>
# grid_3_voltage_level_in_kilo_volts
# <class 'str'>
# transformer_apparent_power_in_mega_volt_ampere
# <class 'str'>
# length_from_bus_2_to_bus_3_in_km
# <class 'str'>
# blackout_start_time_in_hours
# <class 'str'>
# blackout_stop_time_in_hours
# <class 'str'>
# save_plots
# <class 'str'>
# photovoltaic_generation_data_file_path
# <class 'str'>
# electric_load_data_file_path
# <class 'str'>
# data_strategy
# <class 'str'>
# ambient_temperature_file_path
# <class 'str'>
# market
# <class 'str'>
# import_period_prices.P1
# <class 'str'>
# import_period_prices.P2
# <class 'str'>
# import_period_prices.P3
# <class 'str'>
# import_period_prices.P4
# <class 'str'>
# import_period_prices.P5
# <class 'str'>
# import_period_prices.P6
# <class 'str'>
# buses_voltage_angle_in_degrees
# <class 'str'>
# buses_active_power_in_kilowatts
# <class 'str'>
# buses_reactive_power_in_kilovolt_ampere_reactive
# <class 'str'>
# market_active_power_in_kilowatts
# <class 'str'>
# market_reactive_power_in_kilovolt_ampere_reactive
# <class 'str'>
# buses_voltage_in_per_unit
# <class 'str'>
# active_power_demand_in_kilowatts
# <class 'str'>
# revenue
# <class 'str'>
# active_power_demand_base_in_kilowatts
# <class 'str'>
# imported_active_power_in_kilowatts
# <class 'str'>
# exported_active_power_in_kilowatts
# <class 'str'>
# building_power_consumption_in_kilowatts
# <class 'str'>
# ambient_temperature_in_degree_celsius
# <class 'str'>
# building_internal_temperature_in_celsius_degrees
# <class 'str'>
# hvac_active_power_in_kilowatts
# <class 'str'>
# storage_asset_accumulated_power_in_kilowatts
# <class 'str'>

# %%
list_columns
# Out:
# ['market_active_power_in_kilowatts',
#  'market_reactive_power_in_kilovolt_ampere_reactive',
#  'active_power_demand_in_kilowatts',
#  'active_power_demand_base_in_kilowatts',
#  'imported_active_power_in_kilowatts',
#  'exported_active_power_in_kilowatts',
#  'building_power_consumption_in_kilowatts',
#  'ambient_temperature_in_degree_celsius',
#  'building_internal_temperature_in_celsius_degrees',
#  'hvac_active_power_in_kilowatts',
#  'storage_asset_accumulated_power_in_kilowatts']

# %%
for list_column in list_columns:
    print(list_column)
    print(len(data[list_column]))
# Out:
# market_active_power_in_kilowatts
# 72
# market_reactive_power_in_kilovolt_ampere_reactive
# 72
# active_power_demand_in_kilowatts
# 72
# active_power_demand_base_in_kilowatts
# 72
# imported_active_power_in_kilowatts
# 72
# exported_active_power_in_kilowatts
# 72
# building_power_consumption_in_kilowatts
# 72
# ambient_temperature_in_degree_celsius
# 72
# building_internal_temperature_in_celsius_degrees
# 72
# hvac_active_power_in_kilowatts
# 72
# storage_asset_accumulated_power_in_kilowatts
# 72

# %%
number_of_rows = data.shape[0]
number_of_rows
# Out:
# 72

# %%
data.iloc[0]
# Out:
# FolderName                                                        20230518-102738_1_Commercial-275-bed Hospital
# rated_photovoltaic_kilowatts                                                                                400
# simulation_time_series_resolution_in_minutes                                                                  1
# energy_management_system_time_series_resolution_in_minutes                                                   15
# max_storage_asset_energy_in_kilowatt_hour                                                                   500
#                                                                                     ...
# building_power_consumption_in_kilowatts                       [[244.16591560715298], [246.72670913556766], [...
# ambient_temperature_in_degree_celsius                         [-3.6851740626763085, -3.9440702927850753, -4....
# building_internal_temperature_in_celsius_degrees              [20.999999999999655, 21.000000000075094, 21.00...
# hvac_active_power_in_kilowatts                                [244.16591560715298, 244.16591560715298, 244.1...
# storage_asset_accumulated_power_in_kilowatts                  [244.16591560715298, 246.72670913556766, 252.0...
# Name: 0, Length: 66, dtype: object

# %%
# for number_of_row in np.arange(0, number_of_rows):
#     row_data = data.iloc[number_of_row]
#     for list_column in list_columns:
#         figure = plt.figure(num=None, figsize=(15, 2), dpi=80, facecolor='w', edgecolor='k')
#         plt.plot(data[list_column][0])
#         case_name = row_data['FolderName']
#         plt.title(f'{case_name} - {list_column}');

# %%
data.shape
# Out:
# (72, 66)

# %%
number_of_columns = data.shape[1]
number_of_plots = number_of_rows * number_of_columns

# %%
# fig = plt.figure()
# for number_of_plot in np.arange(0, number_of_plots):
#     for number_of_row in np.arange(0, number_of_rows):
#         row_data = data.iloc[number_of_row]
#         for list_column in list_columns:
#             ax = fig.add_subplot(number_of_rows, number_of_columns, number_of_plot + 1)
#             ax.plot(row_data[list_column])

# %%
# for number_of_row in np.arange(0, number_of_rows):
#     row_data = data.iloc[number_of_row]
#     for list_column in list_columns:
#         figure = plt.figure(num=None, figsize=(15, 2), dpi=80, facecolor='w', edgecolor='k')
#         plt.plot(row_data[list_column])
#         case_name = row_data['FolderName']
#         plt.title(f'{case_name} - {list_column}');

# %%
# pp = PdfPages('test.pdf')

# for number_of_row in np.arange(0, number_of_rows):
#     row_data = data.iloc[number_of_row]
#     figure = plt.figure(num=None, figsize=(15, 30), dpi=80, facecolor='w', edgecolor='k')
#     for list_column_index in np.arange(0, len(list_columns)):
#         list_column = list_columns[list_column_index]
#         plt.subplot(12, 1, list_column_index + 1)
#         plt.plot(row_data[list_column])
#         case_name = row_data['FolderName']
#         plt.title(f'{case_name} - {list_column}')
#         figure.tight_layout()

# %%
# %%time
number_of_rows
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 72

# %%
# %%time
for number_of_row in np.arange(0, number_of_rows):
    row_data = data.iloc[number_of_row]
    row_data = data.iloc[number_of_row]
    figure = plt.figure(num=None, figsize=(15, 30), dpi=80, facecolor='w', edgecolor='k')
    for list_column_index in np.arange(0, len(list_columns)):
        list_column = list_columns[list_column_index]
        plt.subplot(12, 1, list_column_index + 1)
        plt.plot(row_data[list_column])
        case_name = row_data['FolderName']
        plt.title(f'{case_name} - {list_column}')
        figure.tight_layout()
    pp = PdfPages(f'plots/{case_name}.pdf')
    pp.savefig()
    pp.close()
    plt.close(figure)
# Out:
# CPU times: total: 55.3 s
# Wall time: 1min

# %% [markdown]
# # Format the plots

# %%
test_data = data.iloc[0]
test_data
# Out:
# FolderName                                                        20230518-102738_1_Commercial-275-bed Hospital
# rated_photovoltaic_kilowatts                                                                                400
# simulation_time_series_resolution_in_minutes                                                                  1
# energy_management_system_time_series_resolution_in_minutes                                                   15
# max_storage_asset_energy_in_kilowatt_hour                                                                   500
#                                                                                     ...
# building_power_consumption_in_kilowatts                       [[244.16591560715298], [246.72670913556766], [...
# ambient_temperature_in_degree_celsius                         [-3.6851740626763085, -3.9440702927850753, -4....
# building_internal_temperature_in_celsius_degrees              [20.999999999999655, 21.000000000075094, 21.00...
# hvac_active_power_in_kilowatts                                [244.16591560715298, 244.16591560715298, 244.1...
# storage_asset_accumulated_power_in_kilowatts                  [244.16591560715298, 246.72670913556766, 252.0...
# Name: 0, Length: 66, dtype: object

# %%
type((test_data['active_power_demand_base_in_kilowatts']))
# Out:
# list

# %%
def plot_demand_base_and_total_imported_power(simulation_time_series_resolution_in_hours: float,
                                              number_of_time_intervals_per_day: int,
                                              active_power_demand_base_in_kilowatts: np.ndarray,
                                              market_active_power_in_kilowatts: np.ndarray, case: str,
                                              revenue: float, current_time: str, plots_path: Union[str, None],
                                              save_plot: bool) -> None:
    hours = simulation_time_series_resolution_in_hours * np.arange(number_of_time_intervals_per_day)
    max_time = max(hours)
    figure = plt.figure(num=None, figsize=(15, 5), dpi=80, facecolor='w', edgecolor='k')
    plt.plot(hours, active_power_demand_base_in_kilowatts, '--', label='Demand')
    plt.plot(hours, market_active_power_in_kilowatts, label='Imports')
    plt.suptitle('Base Demand vs Imports from the Network')
    subtitle = 'Case: ' + str(case) + ' - ' + 'Revenue[€]: ' + str(revenue)
    plt.title(subtitle)
    plt.ylabel('Power [kW]')
    plt.xlabel('Time [h]')
    plt.xlim(0, max_time)
    plt.xticks(np.arange(0, max_time, step=1))
    plt.legend()
    plt.grid(True, alpha=0.5)
    plt.tight_layout()
    if save_plot:
        figure.savefig(f'{plots_path}/{current_time}_{case}_demand_base_and_total_imported_power.png')
    else:
        plt.show()

# %%
hours_per_day = 24
simulation_time_series_resolution_in_minutes = test_data['simulation_time_series_resolution_in_minutes']
simulation_time_series_resolution_in_hours = simulation_time_series_resolution_in_minutes / 60
number_of_time_intervals_per_day = int(hours_per_day / simulation_time_series_resolution_in_hours)
active_power_demand_base_in_kilowatts = test_data['active_power_demand_base_in_kilowatts']
market_active_power_in_kilowatts = test_data['market_active_power_in_kilowatts']
case = test_data['FolderName']
revenue = test_data['revenue']
current_time = datetime.now().strftime("%Y%m%d-%H%M%S")
plots_path = None
save_plot = False


plot_demand_base_and_total_imported_power(
    simulation_time_series_resolution_in_hours=simulation_time_series_resolution_in_hours,
    number_of_time_intervals_per_day=number_of_time_intervals_per_day,
    active_power_demand_base_in_kilowatts=active_power_demand_base_in_kilowatts,
    market_active_power_in_kilowatts=market_active_power_in_kilowatts,
    case=case,
    revenue=revenue,
    current_time=current_time,
    plots_path=plots_path,
    save_plot=save_plot
)

# %%
list_columns
# Out:
# ['market_active_power_in_kilowatts',
#  'market_reactive_power_in_kilovolt_ampere_reactive',
#  'active_power_demand_in_kilowatts',
#  'active_power_demand_base_in_kilowatts',
#  'imported_active_power_in_kilowatts',
#  'exported_active_power_in_kilowatts',
#  'building_power_consumption_in_kilowatts',
#  'ambient_temperature_in_degree_celsius',
#  'building_internal_temperature_in_celsius_degrees',
#  'hvac_active_power_in_kilowatts',
#  'storage_asset_accumulated_power_in_kilowatts']

# %%
data_length = len(test_data['imported_active_power_in_kilowatts'])
simulation_time_series_resolution_in_hours = hours_per_day / data_length
print(number_of_time_intervals_per_day)
new_hours = np.arange(start=0, stop=hours_per_day , step=simulation_time_series_resolution_in_hours)
# Out:
# 1440

# %%
len(new_hours)
# Out:
# 96

# %%
figure = plt.figure(figsize=(15, 5))
plt.plot(new_hours, test_data['imported_active_power_in_kilowatts'], label='Imported Active Power')
plt.plot(new_hours, test_data['exported_active_power_in_kilowatts'], label='Exported Active Power')
plt.plot(new_hours, test_data['building_power_consumption_in_kilowatts'], label='Stored Active Power')
plt.xticks(np.arange(0, new_hours[-1] + 1, step=1))
plt.grid(True, alpha=0.5)
plt.legend()

# %%
def downsample_array_with_average_values(array_to_resample: np.array, resample_length: int) -> np.array:
    array_to_resample_length = len(array_to_resample)
    batch_size = int(array_to_resample_length / resample_length)
    average_list = []
    for index in np.arange(start=0, stop=array_to_resample_length, step=batch_size):
        average_value = np.mean(array_to_resample[index: index+batch_size])
        average_list.append(average_value)
    return np.array(average_list[:resample_length])

# %%
array_to_resample = np.array(test_data['active_power_demand_base_in_kilowatts'])
resample_length = len(test_data['imported_active_power_in_kilowatts'])
resampled_active_power_demand_base_in_kilowatts = downsample_array_with_average_values(array_to_resample=array_to_resample, resample_length=resample_length)

# %%
figure = plt.figure(figsize=(15, 5))
plt.plot(new_hours, test_data['imported_active_power_in_kilowatts'], label='Imported Active Power')
plt.plot(new_hours, test_data['exported_active_power_in_kilowatts'], label='Exported Active Power')
plt.plot(new_hours, test_data['building_power_consumption_in_kilowatts'], label='Stored Active Power')
plt.plot(new_hours, resampled_active_power_demand_base_in_kilowatts, label='Active Power Demand Base')
plt.xticks(np.arange(0, new_hours[-1] + 1, step=1))
plt.xlabel('Hours')
plt.ylabel('Active Power [kW]')
plt.grid(True, alpha=0.5)
plt.legend();
