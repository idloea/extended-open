# %% [markdown]
# # Analysis for 20220517-210059.xlsx

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
from ast import literal_eval
from typing import List
pd.set_option('display.max_columns', None)

# %%
excel_sheet_path = r'C:\python\personal\my-open\notebooks\20230517-210059\data\20230517-210059.xlsx'
data = pd.read_excel(excel_sheet_path, engine='openpyxl')

# %%
data.head()
# Out:
#                                       FolderName  \
# 0  20230517-210154_1_Commercial-275-bed Hospital
# 1  20230517-210242_2_Commercial-275-bed Hospital
# 2  20230517-210330_3_Commercial-275-bed Hospital
# 3  20230517-210418_4_Commercial-275-bed Hospital
# 4  20230518-093423_5_Commercial-275-bed Hospital
#
#    rated_photovoltaic_kilowatts  simulation_time_series_resolution_in_minutes  \
# 0                           400                                             1
# 1                           400                                             1
# 2                           400                                             1
# 3                           400                                             1
# 4                           400                                             1
#
#    energy_management_system_time_series_resolution_in_minutes  \
# 0                                                 15
# 1                                                 15
# 2                                                 15
# 3                                                 15
# 4                                                 15
#
#    max_storage_asset_energy_in_kilowatt_hour  \
# 0                                        500
# 1                                        500
# 2                                        500
# 3                                        500
# 4                                        500
#
#    min_storage_asset_energy_in_kilowatt_hour  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
#    max_storage_asset_active_power_in_kilowatts  \
# 0                                          500
# 1                                          500
# 2                                          500
# 3                                          500
# 4                                          500
#
#    min_storage_asset_active_power_in_kilowatts  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    initial_storage_asset_energy_level_percentage  \
# 0                                              4
# 1                                              4
# 2                                              4
# 3                                              4
# 4                                              4
#
#    required_storage_asset_terminal_energy_level_percentage  \
# 0                                                 50
# 1                                                 50
# 2                                                 50
# 3                                                 50
# 4                                                 50
#
#    storage_asset_absolute_active_power_in_kilowatts  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    storage_asset_degradation_ratio_in_euros_per_kilowatt_hour  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    storage_asset_charging_efficiency_percentage  \
# 0                                           100
# 1                                           100
# 2                                           100
# 3                                           100
# 4                                           100
#
#    storage_asset_charging_efficiency_for_the_optimizer_percentage  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#    max_inside_degree_celsius  min_inside_degree_celsius  \
# 0                         25                         21
# 1                         25                         21
# 2                         25                         21
# 3                         25                         21
# 4                         25                         21
#
#    initial_inside_degree_celsius  max_consumed_electric_heating_kilowatts  \
# 0                             21                                      400
# 1                             21                                      400
# 2                             21                                      400
# 3                             21                                      400
# 4                             21                                      400
#
#    max_consumed_electric_cooling_kilowatts  \
# 0                                      400
# 1                                      400
# 2                                      400
# 3                                      400
# 4                                      400
#
#    heat_pump_coefficient_of_performance  chiller_coefficient_of_performance  \
# 0                                     3                                   1
# 1                                     3                                   1
# 2                                     3                                   1
# 3                                     3                                   1
# 4                                     3                                   1
#
#    building_thermal_capacitance_in_kilowatts_hour_per_degree_celsius  \
# 0                                                500
# 1                                                500
# 2                                                500
# 3                                                500
# 4                                                500
#
#    building_thermal_resistance_in_degree_celsius_per_kilowatts  \
# 0                                             0.0337
# 1                                             0.0337
# 2                                             0.0337
# 3                                             0.0337
# 4                                             0.0337
#
#    export_prices_in_euros_per_kilowatt_hour  \
# 0                                     0.189
# 1                                     0.189
# 2                                     0.189
# 3                                     0.189
# 4                                     0.189
#
#    demand_charge_in_euros_per_kilowatt  max_import_kilowatts  \
# 0                                    0                   500
# 1                                    0                   500
# 2                                    0                   500
# 3                                    0                   500
# 4                                    0                   500
#
#    max_export_kilowatts  offered_kilowatts_in_frequency_response  \
# 0                  -500                                        0
# 1                  -500                                        0
# 2                  -500                                        0
# 3                  -500                                        0
# 4                  -500                                        0
#
#    max_frequency_response_state_of_charge  \
# 0                                     0.6
# 1                                     0.6
# 2                                     0.6
# 3                                     0.6
# 4                                     0.6
#
#    min_frequency_response_state_of_charge  \
# 0                                     0.4
# 1                                     0.4
# 2                                     0.4
# 3                                     0.4
# 4                                     0.4
#
#    frequency_response_price_in_euros_per_kilowatt_hour  \
# 0                                             0.0059
# 1                                             0.0059
# 2                                             0.0059
# 3                                             0.0059
# 4                                             0.0059
#
#    grid_1_voltage_level_in_kilo_volts  grid_2_voltage_level_in_kilo_volts  \
# 0                                  20                                 0.4
# 1                                  20                                 0.4
# 2                                  20                                 0.4
# 3                                  20                                 0.4
# 4                                  20                                 0.4
#
#    grid_3_voltage_level_in_kilo_volts  \
# 0                                 0.4
# 1                                 0.4
# 2                                 0.4
# 3                                 0.4
# 4                                 0.4
#
#    transformer_apparent_power_in_mega_volt_ampere  \
# 0                                             0.4
# 1                                             0.4
# 2                                             0.4
# 3                                             0.4
# 4                                             0.4
#
#    length_from_bus_2_to_bus_3_in_km  blackout_start_time_in_hours  \
# 0                               0.1                            11
# 1                               0.1                            11
# 2                               0.1                            11
# 3                               0.1                            11
# 4                               0.1                            11
#
#    blackout_stop_time_in_hours  save_plots  \
# 0                         12.5       False
# 1                         12.5       False
# 2                         12.5       False
# 3                         12.5       False
# 4                         12.5       False
#
#               photovoltaic_generation_data_file_path  \
# 0  data/solar_radiation/pamplona/1_min/2022-01-01...
# 1  data/solar_radiation/pamplona/1_min/2022-01-02...
# 2  data/solar_radiation/pamplona/1_min/2022-01-03...
# 3  data/solar_radiation/pamplona/1_min/2022-01-04...
# 4  data/solar_radiation/pamplona/1_min/2022-01-05...
#
#                     electric_load_data_file_path data_strategy  \
# 0  data/electric_loads/considered_building_types  MeteoNavarra
# 1  data/electric_loads/considered_building_types  MeteoNavarra
# 2  data/electric_loads/considered_building_types  MeteoNavarra
# 3  data/electric_loads/considered_building_types  MeteoNavarra
# 4  data/electric_loads/considered_building_types  MeteoNavarra
#
#                        ambient_temperature_file_path   market  \
# 0  data/ambient_temperature/pamplona/20220115_amb...  Spanish
# 1  data/ambient_temperature/pamplona/20220215_amb...  Spanish
# 2  data/ambient_temperature/pamplona/20220315_amb...  Spanish
# 3  data/ambient_temperature/pamplona/20220415_amb...  Spanish
# 4  data/ambient_temperature/pamplona/20220515_amb...  Spanish
#
#    import_period_prices.P1  import_period_prices.P2  import_period_prices.P3  \
# 0                   0.1395                   0.1278                    0.111
# 1                   0.1395                   0.1278                    0.111
# 2                   0.1395                   0.1278                    0.111
# 3                   0.1395                   0.1278                    0.111
# 4                   0.1395                   0.1278                    0.111
#
#    import_period_prices.P4  import_period_prices.P5  import_period_prices.P6  \
# 0                   0.1014                   0.0927                   0.0871
# 1                   0.1014                   0.0927                   0.0871
# 2                   0.1014                   0.0927                   0.0871
# 3                   0.1014                   0.0927                   0.0871
# 4                   0.1014                   0.0927                   0.0871
#
#                       buses_voltage_angle_in_degrees  \
# 0  [[0.0, -2.3951697643387164, -3.259090153682367...
# 1  [[0.0, -1.5797317440054035, -2.145666664095071...
# 2  [[0.0, -0.8147567975550066, -1.104240168130317...
# 3  [[0.0, -1.0248455780610335, -1.389971268381915...
# 4  [[0.0, -0.7142447014344591, -0.967611137719895...
#
#                      buses_active_power_in_kilowatts  \
# 0  [[-288.1100621061704, 0.0, 250.71931560876405]...
# 1  [[-190.20332931710308, 0.0, 173.2503747170207]...
# 2  [[-98.3657717213743, 0.0, 92.9024722460945], [...
# 3  [[-123.58075645120803, 0.0, 115.7000132121146]...
# 4  [[-86.30505265465385, 0.0, 81.80117101603292],...
#
#     buses_reactive_power_in_kilovolt_ampere_reactive  \
# 0  [[-16.35650436202681, 0.0, 0.0], [-16.35650436...
# 1  [[-7.093392131914574, 0.0, 0.0], [-7.093392131...
# 2  [[-1.878627503088791, 0.0, 0.0], [-1.878627503...
# 3  [[-2.976985199600601, 0.0, 0.0], [-2.976985199...
# 4  [[-1.4423141520670528, 0.0, 0.0], [-1.44231415...
#
#                     market_active_power_in_kilowatts  \
# 0  [288.1100621061704, 288.1100621061704, 288.110...
# 1  [190.20332931710308, 190.20332931710308, 190.2...
# 2  [98.3657717213743, 98.3657717213743, 98.365771...
# 3  [123.58075645120803, 123.58075645120803, 123.5...
# 4  [86.30505265465385, 86.30505265465385, 86.3050...
#
#    market_reactive_power_in_kilovolt_ampere_reactive  \
# 0  [16.35650436202681, 16.35650436202681, 16.3565...
# 1  [7.093392131914574, 7.093392131914574, 7.09339...
# 2  [1.878627503088791, 1.878627503088791, 1.87862...
# 3  [2.976985199600601, 2.976985199600601, 2.97698...
# 4  [1.4423141520670528, 1.4423141520670528, 1.442...
#
#                            buses_voltage_in_per_unit  \
# 0  [[1.0, 0.9882421049296655, 0.8728775078644493]...
# 1  [[1.0, 0.9925930000278556, 0.9167119360105046]...
# 2  [[1.0, 0.9963474269620033, 0.9573989107030836]...
# 3  [[1.0, 0.995347756299463, 0.9462667431553236],...
# 4  [[1.0, 0.9968173001728816, 0.9627136200569099]...
#
#                     active_power_demand_in_kilowatts  revenue  \
# 0  [6.553399999999999, 6.553399999999999, 6.55339...   837.49
# 1  [6.8292, 6.8292, 6.8292, 6.8292, 6.91179999999...   583.82
# 2  [5.9486, 5.9486, 5.9486, 5.9486, 5.98640000000...    86.16
# 3  [5.483800000000001, 5.483800000000001, 5.48380...   254.95
# 4  [5.758200000000001, 5.758200000000001, 5.75820...   -41.03
#
#                active_power_demand_base_in_kilowatts  \
# 0  [6.553400000000001, 6.553400000000001, 6.55340...
# 1  [6.8292, 6.8292, 6.8292, 6.8292, 6.8292, 6.829...
# 2  [5.9486, 5.9486, 5.9486, 5.9486, 5.9486, 5.948...
# 3  [5.4838000000000005, 5.4838000000000005, 5.483...
# 4  [5.7582, 5.7582, 5.7582, 5.7582, 5.7582, 5.758...
#
#                   imported_active_power_in_kilowatts  \
# 0  [[499.9999999981634], [499.9999999981608], [49...
# 1  [[499.9999999605623], [499.99999996051207], [4...
# 2  [[499.99999991232636], [499.99999991267646], [...
# 3  [[499.9999999905912], [499.9999999906174], [49...
# 4  [[499.9999999662609], [499.9999999662787], [49...
#
#                   exported_active_power_in_kilowatts  \
# 0  [[249.28068438939937], [246.71989086095172], [...
# 1  [[326.74962524354174], [327.44164314720524], [...
# 2  [[407.0975276662319], [410.03110381635304], [4...
# 3  [[384.29998677847664], [373.6164212920582], [3...
# 4  [[418.19882895022755], [404.19706222472087], [...
#
#              building_power_consumption_in_kilowatts  \
# 0  [[244.16591560715298], [246.72670913556766], [...
# 1  [[166.42117467358946], [165.72915676985767], [...
# 2  [[86.9538721655212], [84.02029601456186], [84....
# 3  [[110.21621320192189], [120.89977868838022], [...
# 4  [[76.04297097945201], [90.04473770500485], [91...
#
#                ambient_temperature_in_degree_celsius  \
# 0  [-3.6851740626763085, -3.9440702927850753, -4....
# 1  [4.174819364103925, 4.244782243962801, 4.10928...
# 2  [12.208963769453646, 12.505548100028602, 12.42...
# 3  [9.857140880334313, 8.777032376115372, 8.98475...
# 4  [13.312055782015861, 11.896477041113585, 11.74...
#
#     building_internal_temperature_in_celsius_degrees  \
# 0  [20.999999999999655, 21.000000000075094, 21.00...
# 1  [20.99999999999969, 21.000000001803855, 21.000...
# 2  [20.99999999999927, 21.000000003572673, 21.000...
# 3  [20.999999999999446, 21.000000000511797, 21.00...
# 4  [20.99999999976173, 21.00000000168883, 21.0000...
#
#                       hvac_active_power_in_kilowatts  \
# 0  [244.16591560715298, 244.16591560715298, 244.1...
# 1  [166.42117467358946, 166.42117467358946, 166.4...
# 2  [86.9538721655212, 86.9538721655212, 86.953872...
# 3  [110.21621320192189, 110.21621320192189, 110.2...
# 4  [76.04297097945201, 76.04297097945201, 76.0429...
#
#         storage_asset_accumulated_power_in_kilowatts
# 0  [244.16591560715298, 246.72670913556766, 252.0...
# 1  [166.42117467358946, 165.72915676985767, 167.0...
# 2  [86.9538721655212, 84.02029601456186, 84.77945...
# 3  [110.21621320192189, 120.89977868838022, 118.8...
# 4  [76.04297097945201, 90.04473770500485, 91.5328...

# %%
data.columns
# Out:
# Index(['FolderName', 'rated_photovoltaic_kilowatts',
#        'simulation_time_series_resolution_in_minutes',
#        'energy_management_system_time_series_resolution_in_minutes',
#        'max_storage_asset_energy_in_kilowatt_hour',
#        'min_storage_asset_energy_in_kilowatt_hour',
#        'max_storage_asset_active_power_in_kilowatts',
#        'min_storage_asset_active_power_in_kilowatts',
#        'initial_storage_asset_energy_level_percentage',
#        'required_storage_asset_terminal_energy_level_percentage',
#        'storage_asset_absolute_active_power_in_kilowatts',
#        'storage_asset_degradation_ratio_in_euros_per_kilowatt_hour',
#        'storage_asset_charging_efficiency_percentage',
#        'storage_asset_charging_efficiency_for_the_optimizer_percentage',
#        'max_inside_degree_celsius', 'min_inside_degree_celsius',
#        'initial_inside_degree_celsius',
#        'max_consumed_electric_heating_kilowatts',
#        'max_consumed_electric_cooling_kilowatts',
#        'heat_pump_coefficient_of_performance',
#        'chiller_coefficient_of_performance',
#        'building_thermal_capacitance_in_kilowatts_hour_per_degree_celsius',
#        'building_thermal_resistance_in_degree_celsius_per_kilowatts',
#        'export_prices_in_euros_per_kilowatt_hour',
#        'demand_charge_in_euros_per_kilowatt', 'max_import_kilowatts',
#        'max_export_kilowatts', 'offered_kilowatts_in_frequency_response',
#        'max_frequency_response_state_of_charge',
#        'min_frequency_response_state_of_charge',
#        'frequency_response_price_in_euros_per_kilowatt_hour',
#        'grid_1_voltage_level_in_kilo_volts',
#        'grid_2_voltage_level_in_kilo_volts',
#        'grid_3_voltage_level_in_kilo_volts',
#        'transformer_apparent_power_in_mega_volt_ampere',
#        'length_from_bus_2_to_bus_3_in_km', 'blackout_start_time_in_hours',
#        'blackout_stop_time_in_hours', 'save_plots',
#        'photovoltaic_generation_data_file_path',
#        'electric_load_data_file_path', 'data_strategy',
#        'ambient_temperature_file_path', 'market', 'import_period_prices.P1',
#        'import_period_prices.P2', 'import_period_prices.P3',
#        'import_period_prices.P4', 'import_period_prices.P5',
#        'import_period_prices.P6', 'buses_voltage_angle_in_degrees',
#        'buses_active_power_in_kilowatts',
#        'buses_reactive_power_in_kilovolt_ampere_reactive',
#        'market_active_power_in_kilowatts',
#        'market_reactive_power_in_kilovolt_ampere_reactive',
#        'buses_voltage_in_per_unit', 'active_power_demand_in_kilowatts',
#        'revenue', 'active_power_demand_base_in_kilowatts',
#        'imported_active_power_in_kilowatts',
#        'exported_active_power_in_kilowatts',
#        'building_power_consumption_in_kilowatts',
#        'ambient_temperature_in_degree_celsius',
#        'building_internal_temperature_in_celsius_degrees',
#        'hvac_active_power_in_kilowatts',
#        'storage_asset_accumulated_power_in_kilowatts'],
#       dtype='object')

# %%
# Excel gets the arrays as string so that we need to perform the following
for column in data.columns:
    try:
        data[column] = data[column].apply(literal_eval)
    except:
        print(f'Not possible to perform literal_eval in {column}')
# Out:
# Not possible to perform literal_eval in FolderName
# Not possible to perform literal_eval in rated_photovoltaic_kilowatts
# Not possible to perform literal_eval in simulation_time_series_resolution_in_minutes
# Not possible to perform literal_eval in energy_management_system_time_series_resolution_in_minutes
# Not possible to perform literal_eval in max_storage_asset_energy_in_kilowatt_hour
# Not possible to perform literal_eval in min_storage_asset_energy_in_kilowatt_hour
# Not possible to perform literal_eval in max_storage_asset_active_power_in_kilowatts
# Not possible to perform literal_eval in min_storage_asset_active_power_in_kilowatts
# Not possible to perform literal_eval in initial_storage_asset_energy_level_percentage
# Not possible to perform literal_eval in required_storage_asset_terminal_energy_level_percentage
# Not possible to perform literal_eval in storage_asset_absolute_active_power_in_kilowatts
# Not possible to perform literal_eval in storage_asset_degradation_ratio_in_euros_per_kilowatt_hour
# Not possible to perform literal_eval in storage_asset_charging_efficiency_percentage
# Not possible to perform literal_eval in storage_asset_charging_efficiency_for_the_optimizer_percentage
# Not possible to perform literal_eval in max_inside_degree_celsius
# Not possible to perform literal_eval in min_inside_degree_celsius
# Not possible to perform literal_eval in initial_inside_degree_celsius
# Not possible to perform literal_eval in max_consumed_electric_heating_kilowatts
# Not possible to perform literal_eval in max_consumed_electric_cooling_kilowatts
# Not possible to perform literal_eval in heat_pump_coefficient_of_performance
# Not possible to perform literal_eval in chiller_coefficient_of_performance
# Not possible to perform literal_eval in building_thermal_capacitance_in_kilowatts_hour_per_degree_celsius
# Not possible to perform literal_eval in building_thermal_resistance_in_degree_celsius_per_kilowatts
# Not possible to perform literal_eval in export_prices_in_euros_per_kilowatt_hour
# Not possible to perform literal_eval in demand_charge_in_euros_per_kilowatt
# Not possible to perform literal_eval in max_import_kilowatts
# Not possible to perform literal_eval in max_export_kilowatts
# Not possible to perform literal_eval in offered_kilowatts_in_frequency_response
# Not possible to perform literal_eval in max_frequency_response_state_of_charge
# Not possible to perform literal_eval in min_frequency_response_state_of_charge
# Not possible to perform literal_eval in frequency_response_price_in_euros_per_kilowatt_hour
# Not possible to perform literal_eval in grid_1_voltage_level_in_kilo_volts
# Not possible to perform literal_eval in grid_2_voltage_level_in_kilo_volts
# Not possible to perform literal_eval in grid_3_voltage_level_in_kilo_volts
# Not possible to perform literal_eval in transformer_apparent_power_in_mega_volt_ampere
# Not possible to perform literal_eval in length_from_bus_2_to_bus_3_in_km
# Not possible to perform literal_eval in blackout_start_time_in_hours
# Not possible to perform literal_eval in blackout_stop_time_in_hours
# Not possible to perform literal_eval in save_plots
# Not possible to perform literal_eval in photovoltaic_generation_data_file_path
# Not possible to perform literal_eval in electric_load_data_file_path
# Not possible to perform literal_eval in data_strategy
# Not possible to perform literal_eval in ambient_temperature_file_path
# Not possible to perform literal_eval in market
# Not possible to perform literal_eval in import_period_prices.P1
# Not possible to perform literal_eval in import_period_prices.P2
# Not possible to perform literal_eval in import_period_prices.P3
# Not possible to perform literal_eval in import_period_prices.P4
# Not possible to perform literal_eval in import_period_prices.P5
# Not possible to perform literal_eval in import_period_prices.P6
# Not possible to perform literal_eval in buses_voltage_angle_in_degrees
# Not possible to perform literal_eval in buses_active_power_in_kilowatts
# Not possible to perform literal_eval in buses_reactive_power_in_kilovolt_ampere_reactive
# Not possible to perform literal_eval in buses_voltage_in_per_unit
# Not possible to perform literal_eval in revenue

# %%
simulation_time_series_resolution_in_hours = data.simulation_time_series_resolution_in_minutes[0] / 60
hours_per_day = 24
number_of_time_intervals_per_day = int(hours_per_day / simulation_time_series_resolution_in_hours)

# %%
hours = simulation_time_series_resolution_in_hours * np.arange(number_of_time_intervals_per_day)
max_time = max(hours)
figure = plt.figure(num=None, figsize=(11, 4), dpi=80, facecolor='w', edgecolor='k')
plt.plot(hours, data.active_power_demand_base_in_kilowatts[0], '--', label='Demand')
plt.plot(hours, data.market_active_power_in_kilowatts[0], label='Imports')
plt.suptitle('Base Demand vs Imports from the Network')
subtitle = 'Case: ' + str(data.FolderName[0]) + ' - ' + 'Revenue[€]: ' + str(data.revenue[0])
plt.title(subtitle)
plt.ylabel('Power [kW]')
plt.xlabel('Time [h]')
plt.xlim(0, max_time)
plt.xticks(np.arange(0, max_time, step=1))
plt.legend()
plt.grid(True, alpha=0.5)
plt.tight_layout()

# %%
list_columns = []
for column in data.columns:
    if isinstance(data[column][0], list):
        list_columns.append(column)

# %%
list_columns
# Out:
# ['market_active_power_in_kilowatts',
#  'market_reactive_power_in_kilovolt_ampere_reactive',
#  'active_power_demand_in_kilowatts',
#  'active_power_demand_base_in_kilowatts',
#  'imported_active_power_in_kilowatts',
#  'exported_active_power_in_kilowatts',
#  'building_power_consumption_in_kilowatts',
#  'ambient_temperature_in_degree_celsius',
#  'building_internal_temperature_in_celsius_degrees',
#  'hvac_active_power_in_kilowatts',
#  'storage_asset_accumulated_power_in_kilowatts']

# %%
number_of_rows = data.shape[0]
number_of_rows
# Out:
# 9

# %%
data.iloc[0]
# Out:
# FolderName                                                        20230517-210154_1_Commercial-275-bed Hospital
# rated_photovoltaic_kilowatts                                                                                400
# simulation_time_series_resolution_in_minutes                                                                  1
# energy_management_system_time_series_resolution_in_minutes                                                   15
# max_storage_asset_energy_in_kilowatt_hour                                                                   500
#                                                                                     ...
# building_power_consumption_in_kilowatts                       [[244.16591560715298], [246.72670913556766], [...
# ambient_temperature_in_degree_celsius                         [-3.6851740626763085, -3.9440702927850753, -4....
# building_internal_temperature_in_celsius_degrees              [20.999999999999655, 21.000000000075094, 21.00...
# hvac_active_power_in_kilowatts                                [244.16591560715298, 244.16591560715298, 244.1...
# storage_asset_accumulated_power_in_kilowatts                  [244.16591560715298, 246.72670913556766, 252.0...
# Name: 0, Length: 66, dtype: object

# %%
# for number_of_row in np.arange(0, number_of_rows):
#     row_data = data.iloc[number_of_row]
#     for list_column in list_columns:
#         figure = plt.figure(num=None, figsize=(15, 2), dpi=80, facecolor='w', edgecolor='k')
#         plt.plot(data[list_column][0])
#         case_name = row_data['FolderName']
#         plt.title(f'{case_name} - {list_column}');

# %%
data.shape
# Out:
# (9, 66)

# %%
number_of_columns = data.shape[1]
number_of_plots = number_of_rows * number_of_columns

# %%
# fig = plt.figure()
# for number_of_plot in np.arange(0, number_of_plots):
#     for number_of_row in np.arange(0, number_of_rows):
#         row_data = data.iloc[number_of_row]
#         for list_column in list_columns:
#             ax = fig.add_subplot(number_of_rows, number_of_columns, number_of_plot + 1)
#             ax.plot(row_data[list_column])

# %%
for number_of_row in np.arange(0, number_of_rows):
    row_data = data.iloc[number_of_row]
    for list_column in list_columns:
        figure = plt.figure(num=None, figsize=(15, 2), dpi=80, facecolor='w', edgecolor='k')
        plt.plot(row_data[list_column])
        case_name = row_data['FolderName']
        plt.title(f'{case_name} - {list_column}');
# Out:
# C:\Users\IkerDeLoma-Osorio\AppData\Local\Temp\ipykernel_38328\3546177727.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   figure = plt.figure(num=None, figsize=(15, 2), dpi=80, facecolor='w', edgecolor='k')
